# %% [markdown]
# <a href="https://colab.research.google.com/github/joseivangeraldo/Python/blob/main/GUI_IN_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Pessoa:
  "Isto é uma classe nova chamada Pessoa"
  idade = 15

  def saudacao(self):
    print('Olá Pessoas!')

print(Pessoa.idade)
# Out:
# 15

# %%
print(Pessoa.saudacao)
# Out:
# <function Pessoa.saudacao at 0x7a70c3f14ae0>

# %%
print(Pessoa.__doc__)
# Out:
# Isto é uma classe nova chamada Pessoa

# %%
matheus = Pessoa()

# %%
print(matheus.idade)
# Out:
# 15

# %%
# Chamando o método saudacao()
# Output: “Olá Pessoas!”
matheus.saudacao()
# Out:
# Olá Pessoas!

# %%
import math

class Esfera:
  def __init__(self,cor,raio):
    self.cor = cor
    self.raio = raio

  def volume(self):
    vol = (4/3)*math.pi * (self.raio**3)
    return vol

  def area(self):
    ar = 4 * math.pi * (self.raio**2)
    return ar

bola1 = Esfera( 'vermelha', 4 )
bola2 = Esfera( 'azul', 7 )

print(f'O volume da bola 1 é {bola1.volume()} cm^3')
print(f'A área superﬁcial da bola 1 é {bola1.area()} cm^2')

print(bola1.volume())
print(Esfera.volume(bola1))
# Out:
# O volume da bola 1 é 268.082573106329 cm^3
# A área superﬁcial da bola 1 é 201.06192982974676 cm^2
# 268.082573106329
# 268.082573106329

# %%
class Televisor:
  def __init__(self, fab, modelo):
    self.fabricante = fab
    self.modelo = modelo
    self.canal_atual = None
    self.lista_de_canais = ['Globo', 'SBT', 'Bandeirantes', 'Gazeta', 'Record']
    self.volume = 10

  def aumentaVolume(self, valor):
    if self.volume + valor <= 100:
      self.volume += valor
    else:
      self.volume = 100

  def diminuiVolume(self, valor):
    if self.volume - valor >= 0:
      self.volume -= valor
    else:
      self.volume = 0

  def trocaCanal(self, canal ):
    if canal in self.lista_de_canais:
      self.canal_atual = canal
  def sintonizaCanal(self, canal ):
    if canal not in self.lista_de_canais:
      self.lista_de_canais.append(canal)

# %%
class ControleRemoto:
  def __init__(self, tv ):
    self.tv = tv

  def aumentaVolume(self):
    self.tv.aumentaVolume(10)

  def diminuiVolume(self):
    self.tv.diminuiVolume(10)

  def trocaCanal(self, canal):
    self.tv.trocaCanal(canal)

  def sintonizaCanal(self, canal):
    self.tv.sintonizaCanal(canal)

# %%
tv = Televisor('SONY', 'SONY-123')

controle = ControleRemoto(tv)
controle.sintonizaCanal('SBT')
controle.sintonizaCanal('ESPN')
controle.trocaCanal('Globo')
controle.trocaCanal('ESPN')

controle.aumentaVolume()

print(tv.volume)
print(tv.canal_atual)
# Out:
# 20
# ESPN

# %%
controle.diminuiVolume()
controle.diminuiVolume()
controle.diminuiVolume()
print(tv.volume)
# Out:
# 0

# %%
controle.aumentaVolume()
print(tv.volume)
# Out:
# 10

# %%
controle.aumentaVolume()
print(tv.volume)
# Out:
# 20

# %%
controle.aumentaVolume()
print(tv.volume)
# Out:
# 30

# %%
controle.diminuiVolume()
print(tv.volume)
# Out:
# 20
